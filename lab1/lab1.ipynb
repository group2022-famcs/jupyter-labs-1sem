// %% [markdown]
// # Домашняя работа №1

// %% [markdown]
// Перед началом ознакомьтесь с [демо](https://mybinder.org/v2/gh/group2021-famcs/jupyter-labs-1sem/HEAD?filepath=demo/demo.ipynb) по работе с интерактивными ноутбуками.

// %%
#include "helper.h"

// %% [markdown]
// ## Задание 1
// Поменяйте местами значения переменных `x` и `y` тремя способами.

// %% [markdown]
// ### 1.1
// С помощью дополнительной переменной

// %%
int a = 3;
int b = 15;

// Your code goes here

std::cout << a << " " << b << "\n";
// Out:
// Expected output: 15 3

// %% [markdown]
// ### 1.2
// Как обойтись без дополнительной переменной?
//
// <details>
// <summary style="cursor: pointer; text-decoration: underline">Подсказка</summary>
//
// Используйте операторы `+` и `-`, сохраняя необходимые промежуточные результаты в одной из переменных.
// </details>

// %%
int a = 3;
int b = 15;

// Your code goes here

std::cout << a << " " << b << "\n";
// Out:
// Expected output: 15 3

// %% [markdown]
// ### 1.3*
// Как обойтись без дополнительной переменной и используя только один оператор?
//
// <details>
// <summary style="cursor: pointer; text-decoration: underline">Подсказка</summary>
//
// Какими свойствами обладает оператор `^`?
// </details>

// %%
int a = 3;
int b = 15;

// Your code goes here

std::cout << a << " " << b << "\n";
// Out:
// Expected output: 15 3

// %% [markdown]
// Подумайте, чем такой способ лучше предыдущего? В каких случаях результат может отличаться? Напишите ответ ниже:

// %% [markdown]
// ## Задание 2
//
// С начала года прошло `m` секунд. Определите который сейчас час, т.е. сколько прошло часов, минут и секунд от начала текущих суток. Выведите результат в произвольном формате.

// %%
int m = 8676330;

// Your code goes here
// Out:
// 10 hours, 5 minutes, 30 seconds

// %% [markdown]
// ## Задание 3
//
// В следующих арифметических выражениях пропали скобки. Найдите способ расставить наименьшее количество скобок так, чтобы выражение снова стало истинным. Запрещается делать любые изменения, кроме добавления скобок.

// %% [markdown]
// ### 3.1

// %%
-2 + 2 * 2 == -8
// Out:
// true

// %% [markdown]
// ### 3.2

// %%
13 / 7 % 3 * 2 == 13
// Out:
// false

// %% [markdown]
// ### 3.3

// %%
1 == 2 == 2 == 3
// Out:
// false

// %% [markdown]
// ### 3.4

// %%
5 & 9 << 3 + 1 == 16
// Out:
// false

// %% [markdown]
// ### 3.5

// %%
12 & 7 | 5 ^ 3 == 7
// Out:
// false

// %% [markdown]
// ## Задание 4
//
// Даны координаты сторон треугольника. Найдите его периметр, площадь, радиус вписанной и описанной окружностей.

// %%
int x1 = 0;
int y1 = 0;
int x2 = 2;
int y2 = 0;
int x3 = 1;
int y3 = 3;

// Your code goes here
// Out:
// Area: 3, perimeter: 8.32456, inner radius: 0.720759, outer radius: 1.66667

// %% [markdown]
// ## Задание 5
//
// По графику функции угадайте, что это за функция, и реализуйте такую же.

// %% [markdown]
// ### 5.1

// %%
double f1(double x) {
    return 0; // Replace this line
}

test(1, f1)

// %% [markdown]
// ### 5.2

// %%
double f2(double x) {
    return 0; // Replace this line
}

test(2, f2)

// %% [markdown]
// ### 5.3

// %%
double f3(double x) {
    return 0; // Replace this line
}

test(3, f3)

// %% [markdown]
// ### 5.4

// %%
double f4(double x) {
    return 0; // Replace this line
}

test(4, f4)

// %% [markdown]
// ### 5.5
// Использовать условные операторы запрещается!

// %%
double f5(double x) {
    return 0; // Replace this line
}

test(5, f5)

// %% [markdown]
// ### 5.6
// Подсказка: функция имеет вид $a x^3 + b x^2 + c x + d$. Как можно найти неизвестные $a$, $b$, $c$, $d$?

// %%
double f6(double x) {
    return 0; // Replace this line
}

test(6, f6)

// %% [markdown]
// Расскажите, как подбирали коэффициенты:

// %% [markdown]
// ## Задание 6
// Дано вещественное число $a$. Пользуясь только операцией умножения получить (импользуйте удобное именование переменных, например, `a3` для $a$ в кубе, `a8` для $a$ в 8-й степени):
// - $a^4$ за две операции;
// - $a^6$ за три операции;
// - $a^8$ за три операции;
// - $a^{12}$ за четыре операции;
// - $a^{16}$ за четыре операции;
// - $a^{26}$ за шесть операций;
// - $a^{64}$ за шесть операций.
//
// _Не обязательно делать каждый пункт отдельным решением. Достаточно написать общий код, но так, чтобы для выполнения каждого из пунктов в отдельности требовалось только указанное количество операций._

// %%
double a = 10.0;

// Your code goes here

// %% [markdown]
// ## Вот и всё!
// Не забудьте перезапустить все ячейки (`Kernel -> Restart & Run All`) перед сдачей (см. демо).\
// Сохраните заполненный ноутбук, переименуйте своей фамилией (_Ivanov.ipynb_) и отправьте полученный файл (не в архиве) в Anytask (_ДЗ1_).
//
// Опишите, что чувствуете после выполнения работы. Можно в виде картинки
